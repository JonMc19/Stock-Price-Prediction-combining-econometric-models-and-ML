# %%
import yfinance as yf
dat = yf.Ticker("AAPL")

apple_price = dat.history(period="20y", interval="1mo")
#apple_price.to_csv("apple_price.csv")

# %%
apple_price[20:]
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2007-05-01 00:00:00-04:00    2.989703    3.667557    2.958482    3.638137
# 2007-06-01 00:00:00-04:00    3.635437    3.830868    3.464323    3.663656
# 2007-07-01 00:00:00-04:00    3.633934    4.470595    3.581399    3.955450
# 2007-08-01 00:00:00-04:00    4.011888    4.192309    3.350845    4.157185
# 2007-09-01 00:00:00-04:00    4.201015    4.653117    3.902615    4.607186
# ...                               ...         ...         ...         ...
# 2025-04-01 00:00:00-04:00  219.273273  224.640141  168.796836  211.981125
# 2025-05-01 00:00:00-04:00  208.569473  214.036088  192.778125  200.359573
# 2025-06-01 00:00:00-04:00  200.052953  207.154893  194.848867  204.937408
# 2025-07-01 00:00:00-04:00  206.435713  215.984873  205.906315  207.334702
# 2025-08-01 00:00:00-04:00  210.869995  235.119995  201.500000  232.779999
#
#                                 Volume  Dividends  Stock Splits
# Date
# ...
