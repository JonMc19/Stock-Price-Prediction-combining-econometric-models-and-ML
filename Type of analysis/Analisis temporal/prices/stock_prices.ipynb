# %%
from get_prices import get_monthly_quarterly_prices

# %%
tickers = ['AAPL', 'MSFT', 'AMD', 'NKE', 'TSLA']

for ticker in tickers:
    prices = get_monthly_quarterly_prices(ticker)
    print(f"Prices for {ticker}:")
    print(prices)
    prices.to_csv(f'../../../files/prices/{ticker.lower()}_prices.csv', index=True)
    print("\n---------------------------------------------------------------------------------------------\n")
# Out:
# Prices for AAPL:
#           Date       Price calendar_quarter
# 0   2008-09-30    3.412087          Q3 2008
# 1   2008-10-31    3.229864          Q4 2008
# 2   2008-11-30    2.781964          Q4 2008
# 3   2008-12-31    2.562217          Q4 2008
# 4   2009-01-31    2.705713          Q1 2009
# ..         ...         ...              ...
# 200 2025-05-31  200.622314          Q2 2025
# 201 2025-06-30  204.937408          Q2 2025
# 202 2025-07-31  207.334702          Q3 2025
# 203 2025-08-31  232.139999          Q3 2025
# 204 2025-09-30  239.779999          Q3 2025
#
# [205 rows x 3 columns]
#
# ---------------------------------------------------------------------------------------------
#
# Prices for MSFT:
#           Date       Price calendar_quarter
# 0   2008-09-30   19.394426          Q3 2008
# 1   2008-10-31   16.226215          Q4 2008
# 2   2008-11-30   14.792506          Q4 2008
# 3   2008-12-31   14.221873          Q4 2008
# 4   2009-01-31   12.509983          Q1 2009
# ...
