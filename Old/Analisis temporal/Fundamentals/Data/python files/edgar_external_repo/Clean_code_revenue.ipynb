# %% [markdown]
# REPOSITORY CODE

# %%
# -*- coding: utf-8 -*-
"""
Created on Thu Dec  8 16:12:24 2022

@author: ie20391
"""

class edgar_data:
    '''
    To extract data from EDGAR SEC to python dictionary. Attributes of class are:
        - submissions_url - to show link to submissions;
        - data_url - to show link to EDGAR facts;
        - about_company - dict with information about a company;
        - available_data - pd.DataFrame with company's reports;
        - facts - the facts dictionary from EDGAR SEC;
    '''
    
    def __init__(self, company, hdr):
        #cik needs to be of len 10
        self.hdr = hdr
        if type(company) == str:
            self.ticker = company
            self.cik = edgar_data.find_cik(self)
        else:
            self.cik = company
        if len(str(self.cik)) < 10:
                self.cik = str('CIK' + ('0'*(10-len(str(self.cik))))+str(self.cik))
        else:
            raise ValueError('Non-parsable CIK')
        if self.hdr['user-agent'] == None:
            raise ValueError('''Please, specify user-agent requirements, as described in:
                                 
                                 https://www.sec.gov/os/accessing-edgar-data
                                 
                             ''')
        
        self.submissions_url = f"https://data.sec.gov/submissions/{self.cik}.json"
        self.data_url = f'https://data.sec.gov/api/xbrl/companyfacts/{self.cik}.json'
        self.about_company = edgar_data.company_info(self)
        self.available_data = edgar_data.library(self)
        self.facts = edgar_data.access_facts(self)
        
    
    def find_cik(self):
        import requests
        
        ciks_all = requests.get('https://www.sec.gov/files/company_tickers.json',
                                headers = self.hdr).json()
        ciks_all = dict([(val['ticker'], val['cik_str']) for key, val in ciks_all.items()])
        return ciks_all[self.ticker]
    
    def library(self):
        import json
        import requests
        import pandas as pd
        data = json.loads(requests.get(self.submissions_url, headers = self.hdr)._content.decode('utf8'))
        #if there are old filings available, then return df containing all finlings
        if len(data['filings']['files']) !=0:
            prior_submission_number = data['filings']['files'][0]['name']
            old_data = json.loads(requests.get(f'https://data.sec.gov/submissions/{prior_submission_number}',headers = self.hdr
                                               )._content.decode('utf8'))
            df = pd.DataFrame(data = {'rep_date':data['filings']['recent']['reportDate'] + old_data['reportDate'],
                                      'filling_date':data['filings']['recent']['filingDate'] + old_data['filingDate'],
                                      'form':data['filings']['recent']['form'] + old_data['form'],
                                      'xbrl':data['filings']['recent']['isXBRL'] + old_data['isXBRL'],
                                      'accession_num':data['filings']['recent']['accessionNumber'] + old_data['accessionNumber']})
            df = df[((df.form == '10-K') | (df.form == '10-Q')) & (df.xbrl == 1)].sort_values(by = ['rep_date'])
            df.index = [i for i in range(len(df))]
            return df
        else:
            df = pd.DataFrame(data = {'rep_date':data['filings']['recent']['reportDate'],
                                'filling_date':data['filings']['recent']['filingDate'],
                              'form':data['filings']['recent']['form'],
                              'xbrl':data['filings']['recent']['isXBRL'],
                              'accession_num':data['filings']['recent']['accessionNumber']})
        
            df = df[((df.form == '10-K') | (df.form == '10-Q')) & (df.xbrl == 1)].sort_values(by = ['rep_date'])
            df.index = [i for i in range(len(df))]
            return df
    
    def company_info(self):
        import json
        import requests
        data = json.loads(requests.get(self.submissions_url, headers = self.hdr)._content.decode('utf8'))
        d = {}
        if len(data['tickers']) > 0:    
            d['ticker'] = data['tickers'][0]
        else:
            d['ticker'] = None
        if len(data['name']) > 0:
            d['name'] = data['name']
        else:
            d['name'] = None
        if len(data['sic']) > 0:
            d['sic'] = data['sic']
        else:
            d['sic'] = None
        if len(data['sicDescription']) > 0:
            d['sic_descr'] = data['sicDescription']
        else:
            d['sic_descr'] = None
        return d
        
        
    def access_facts(self):
        import json
        import requests
        
        data = json.loads(requests.get(self.data_url, headers = self.hdr)._content.decode('utf8'))
        keys = list(data['facts'].keys())
        
        if 'us-gaap' in keys and 'ifrs-full' in keys:
            if len(data['facts']['us-gaap']) > len(data['facts']['ifrs-full']):
                data = data['facts']['us-gaap']
            else:
                data = data['facts']['ifrs-full']
            return data
        elif 'us-gaap' in keys and 'ifrs-full' not in keys:
            return data['facts']['us-gaap']
        elif 'us-gaap' not in keys and 'ifrs-full' in keys:
            return data['facts']['ifrs-full']
        
if __name__ == '__main__':
    edgar_data

# %% [markdown]
# DEFINE "hdr" AND "apple" to get an instance

# %%
from pprint import pprint

# Paste your edgar_data class definition here

# SEC requires a proper user-agent, for example:
hdr = {
    "user-agent": "Jon jonmcgowan15@gmail.com"
}

# Create an instance for Apple
apple = edgar_data("AAPL", hdr)

# Show basic company info
print("Company Info:")
pprint(apple.about_company)

# Show available filings
print("\nAvailable filings:")
print(apple.available_data.head())

# Show available financial facts keys
print("\nFacts keys:")
print(list(apple.facts.keys())[:20])  # first 20 keys
# Out:
# Company Info:
# {'name': 'Apple Inc.',
#  'sic': '3571',
#  'sic_descr': 'Electronic Computers',
#  'ticker': 'AAPL'}
#
# Available filings:
#      rep_date filling_date  form  xbrl         accession_num
# 0  2009-06-27   2009-07-22  10-Q     1  0001193125-09-153165
# 1  2009-09-26   2009-10-27  10-K     1  0001193125-09-214859
# 2  2009-12-26   2010-01-25  10-Q     1  0001193125-10-012085
# 3  2010-03-27   2010-04-21  10-Q     1  0001193125-10-088957
# 4  2010-06-26   2010-07-21  10-Q     1  0001193125-10-162840
#
# Facts keys:
# ['AccountsPayable', 'AccountsPayableCurrent', 'AccountsReceivableNetCurrent', 'AccruedIncomeTaxesCurrent', 'AccruedIncomeTaxesNoncurrent', 'AccruedLiabilities', 'AccruedLiabilitiesCurrent', 'AccruedMarketingCostsCurrent', 'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment', 'AccumulatedOtherComprehensiveIncomeLossAvailableForSaleSecuritiesAdjustmentNetOfTax', 'AccumulatedOtherComprehensiveIncomeLossCumulativeChangesInNetGainLossFromCashFlowHedgesEffectNetOfTax', 'AccumulatedOtherComprehensiveIncomeLossForeignCurrencyTranslationAdjustmentNetOfTax', 'AccumulatedOtherComprehensiveIncomeLossNetOfTax', 'AdjustmentsToAdditionalPaidInCapitalSharebasedCompensationRequisiteServicePeriodRecognitionValue', 'AdjustmentsToAdditionalPaidInCapitalTaxEffectFromShareBasedCompensation', 'AdvertisingExpense', 'AllocatedShareBasedCompensationExpense', 'AllowanceForDoubtfulAccountsReceivableCurrent', 'AmortizationOfIntangibleAssets', 'AntidilutiveSecuritiesExcludedFromComputationOfEarningsPerShareAmount']

# %% [markdown]
# GET APPLE'S REVENUE

# %%
#Check the different ways revenue might be represented

revenue_tags = [tag for tag in apple.facts.keys() if 'revenue' in tag.lower()]
print(revenue_tags)
# Out:
# ['ContractWithCustomerLiabilityRevenueRecognized', 'DeferredRevenueCurrent', 'DeferredRevenueNoncurrent', 'IncreaseDecreaseInDeferredRevenue', 'RevenueFromContractWithCustomerExcludingAssessedTax', 'Revenues', 'SalesRevenueNet', 'SalesRevenueServicesGross']

# %%
import pandas as pd

def fact_df(fact_name):
    if fact_name in apple.facts:
        df = pd.DataFrame(apple.facts[fact_name]['units']['USD'])
        df['fact'] = fact_name
        return df
    return pd.DataFrame()

# Tags de Revenue
tags = [
    'Revenues',
    'SalesRevenueNet',
    'RevenueFromContractWithCustomerExcludingAssessedTax',
    'ContractWithCustomerLiabilityRevenueRecognized',
    'DeferredRevenueCurrent',
    'DeferredRevenueNoncurrent',
    'IncreaseDecreaseInDeferredRevenue',
    'SalesRevenueServicesGross'
]
df_revenue = pd.concat([fact_df(tag) for tag in tags], ignore_index=True)

# Calcular tipo de periodo basado en duración
df_revenue['start'] = pd.to_datetime(df_revenue['start'])
df_revenue['end'] = pd.to_datetime(df_revenue['end'])
df_revenue['days'] = (df_revenue['end'] - df_revenue['start']).dt.days
df_revenue['Period Type'] = df_revenue['days'].apply(lambda x: 'Annual' if x > 300 else 'Quarterly')

# Limpiar duplicados: mantener el mayor Revenue por periodo
df_revenue = df_revenue.sort_values('val', ascending=False) \
                       .drop_duplicates(subset=['start', 'end', 'Period Type'])

# Ordenar final y renombrar columnas
df_revenue = df_revenue.sort_values('end')
df_revenue = df_revenue[['start', 'end', 'val', 'fact', 'Period Type', 'fp', 'form']]
df_revenue.columns = ['Period Start', 'Period End', 'Revenue (USD)', 'Tag Used', 'Period Type', 'FP', 'Form']

# Add column of lenght in days of the period
df_revenue['Period Length (days)'] = (df_revenue['Period End'] - df_revenue['Period Start']).dt.days

df_revenue[:10]
# Out:
#     Period Start Period End  Revenue (USD)                Tag Used  \
# 12    2006-10-01 2007-09-29    24578000000         SalesRevenueNet
# 14    2008-03-30 2008-06-28     7464000000         SalesRevenueNet
# 13    2007-09-30 2008-06-28    24584000000         SalesRevenueNet
# 414          NaT 2008-09-27     4853000000  DeferredRevenueCurrent
# 17    2007-09-30 2008-09-27    37491000000         SalesRevenueNet
# 19    2008-09-28 2008-12-27    11880000000         SalesRevenueNet
# 21    2008-12-28 2009-03-28     9084000000         SalesRevenueNet
# 20    2008-09-28 2009-03-28    20964000000         SalesRevenueNet
# 24    2008-09-28 2009-06-27    30698000000         SalesRevenueNet
# 416          NaT 2009-06-27     8469000000  DeferredRevenueCurrent
#
#     Period Type  FP    Form  Period Length (days)
# 12       Annual  FY  10-K/A                 363.0
# 14    Quarterly  Q3    10-Q                  90.0
# 13    Quarterly  Q3    10-Q                 272.0
# 414   Quarterly  FY    10-K                   NaN
# 17       Annual  FY    10-K                 363.0
# 19    Quarterly  FY    10-K                  90.0
# 21    Quarterly  Q2    10-Q                  90.0
# 20    Quarterly  Q2    10-Q                 181.0
# 24    Quarterly  Q3    10-Q                 272.0
# 416   Quarterly  Q3    10-Q                   NaN

# %%
#Seperate revenue between annual and quarterly

df_annual = df_revenue[df_revenue['Period Type'] == 'Annual'].reset_index(drop=True)
df_quarterly = df_revenue[df_revenue['Period Type'] == 'Quarterly'].reset_index(drop=True)

# %%
df_annual[:20]
# Out:
#    Period Start Period End  Revenue (USD)  \
# 0    2006-10-01 2007-09-29    24578000000
# 1    2007-09-30 2008-09-27    37491000000
# 2    2008-09-28 2009-09-26    42905000000
# 3    2009-09-27 2010-09-25    65225000000
# 4    2010-09-26 2011-09-24   108249000000
# 5    2011-09-25 2012-09-29   156508000000
# 6    2012-09-30 2013-09-28   170910000000
# 7    2013-09-29 2014-09-27   182795000000
# 8    2014-09-28 2015-09-26   233715000000
# 9    2015-09-27 2016-09-24   215639000000
# 10   2016-09-25 2017-09-30   229234000000
# 11   2017-10-01 2018-09-29   265595000000
# 12   2018-09-30 2019-09-28   260174000000
# 13   2019-09-29 2020-09-26   274515000000
# 14   2020-09-27 2021-09-25   365817000000
# 15   2021-09-26 2022-09-24   394328000000
# 16   2022-09-25 2023-09-30   383285000000
# 17   2023-10-01 2024-09-28   391035000000
#
#                                              Tag Used Period Type    FP  \
# 0                                     SalesRevenueNet      Annual    FY
# 1                                     SalesRevenueNet      Annual    FY
# 2                                     SalesRevenueNet      Annual    FY
# 3                                     SalesRevenueNet      Annual    FY
# 4                                     SalesRevenueNet      Annual    FY
# 5                                     SalesRevenueNet      Annual  None
# 6                                     SalesRevenueNet      Annual    FY
# 7                                     SalesRevenueNet      Annual    FY
# 8                                     SalesRevenueNet      Annual    FY
# 9                                     SalesRevenueNet      Annual    FY
# 10                                           Revenues      Annual    FY
# 11                                           Revenues      Annual    FY
# 12  RevenueFromContractWithCustomerExcludingAssess...      Annual    FY
# 13  RevenueFromContractWithCustomerExcludingAssess...      Annual    FY
# 14  RevenueFromContractWithCustomerExcludingAssess...      Annual    FY
# 15  RevenueFromContractWithCustomerExcludingAssess...      Annual    FY
# 16  RevenueFromContractWithCustomerExcludingAssess...      Annual    FY
# 17  RevenueFromContractWithCustomerExcludingAssess...      Annual    FY
#
#       Form  Period Length (days)
# 0   10-K/A                 363.0
# 1     10-K                 363.0
# 2   10-K/A                 363.0
# 3     10-K                 363.0
# 4      8-K                 363.0
# 5      8-K                 370.0
# 6     10-K                 363.0
# 7     10-K                 363.0
# 8     10-K                 363.0
# 9     10-K                 363.0
# 10    10-K                 370.0
# 11    10-K                 363.0
# 12    10-K                 363.0
# 13    10-K                 363.0
# 14    10-K                 363.0
# 15    10-K                 363.0
# 16    10-K                 370.0
# 17    10-K                 363.0

# %%
#df_quartery contain quarter data with a period of days superior of 90 days, which should be the case for quarterly reports, therefore, we remove instances with period length is over 90 days

df_quarterly = df_quarterly[df_quarterly['Period Length (days)'] <= 95]
df_quarterly[:20]
# Out:
#    Period Start Period End  Revenue (USD)         Tag Used Period Type  FP  \
# 0    2008-03-30 2008-06-28     7464000000  SalesRevenueNet   Quarterly  Q3
# 3    2008-09-28 2008-12-27    11880000000  SalesRevenueNet   Quarterly  FY
# 4    2008-12-28 2009-03-28     9084000000  SalesRevenueNet   Quarterly  Q2
# 8    2009-03-29 2009-06-27     9734000000  SalesRevenueNet   Quarterly  Q3
# 9    2009-06-28 2009-09-26    12207000000  SalesRevenueNet   Quarterly  FY
# 12   2009-09-27 2009-12-26    15683000000  SalesRevenueNet   Quarterly  Q1
# 13   2009-12-27 2010-03-27    13499000000  SalesRevenueNet   Quarterly  FY
# 17   2010-03-28 2010-06-26    15700000000  SalesRevenueNet   Quarterly  Q3
# 19   2010-06-27 2010-09-25    20343000000  SalesRevenueNet   Quarterly  FY
# 22   2010-09-26 2010-12-25    26741000000  SalesRevenueNet   Quarterly  Q1
# 25   2010-12-26 2011-03-26    24667000000  SalesRevenueNet   Quarterly  FY
# 27   2011-03-27 2011-06-25    28571000000  SalesRevenueNet   Quarterly  Q3
# 29   2011-06-26 2011-09-24    28270000000  SalesRevenueNet   Quarterly  FY
# 35   2012-01-01 2012-03-31    39186000000  SalesRevenueNet   Quarterly  FY
# 37   2012-04-01 2012-06-30    35023000000  SalesRevenueNet   Quarterly  FY
# 39   2012-07-01 2012-09-29    35966000000  SalesRevenueNet   Quarterly  FY
# 42   2012-09-30 2012-12-29    54512000000  SalesRevenueNet   Quarterly  FY
# 45   2012-12-30 2013-03-30    43603000000  SalesRevenueNet   Quarterly  Q2
# 48   2013-03-31 2013-06-29    35323000000  SalesRevenueNet   Quarterly  Q3
# 50   2013-06-30 2013-09-28    37472000000  SalesRevenueNet   Quarterly  FY
#
#     Form  Period Length (days)
# 0   10-Q                  90.0
# 3   10-K                  90.0
# 4   10-Q                  90.0
# 8   10-Q                  90.0
# 9   10-K                  90.0
# 12  10-Q                  90.0
# 13  10-K                  90.0
# 17  10-Q                  90.0
# 19  10-K                  90.0
# 22  10-Q                  90.0
# 25   8-K                  90.0
# 27  10-Q                  90.0
# 29  10-K                  90.0
# 35  10-K                  90.0
# 37  10-K                  90.0
# 39  10-K                  90.0
# 42  10-K                  90.0
# 45  10-Q                  90.0
# 48  10-Q                  90.0
# 50  10-K                  90.0

# %% [markdown]
# ADD THE REVENUE OF THE 4 QUARTERS OF EACH FISCAL YEAR TO GET YEARLY REVENUE, ALSO GOOD TO COMPARED TO df_annual

# %%
# 1. Make sure Period End is datetime
df_quarterly['Period End'] = pd.to_datetime(df_quarterly['Period End'])

# 2. Determine Apple's fiscal year
df_quarterly['Fiscal Year'] = df_quarterly['Period End'].apply(
    lambda d: d.year if d.month < 10 else d.year + 1
)

# 3. Calculate annual revenue from quarters
annual_totals = (
    df_quarterly.groupby('Fiscal Year', as_index=False)['Revenue (USD)'].sum()
    .rename(columns={'Revenue (USD)': 'Fiscal Year Revenue'})
)

# 4. Merge the totals back into df_quarterly
df_quarterly = df_quarterly.merge(annual_totals, on='Fiscal Year', how='left')

# Optional: sort by date
revenue = df_quarterly.sort_values(['Fiscal Year', 'Period End']).reset_index(drop=True)


revenue[30:]

#Q1 2012 is missing in the data
# Out:
#    Period Start Period End  Revenue (USD)  \
# 30   2016-03-27 2016-06-25    42358000000
# 31   2016-06-26 2016-09-24    46852000000
# 32   2017-01-01 2017-04-01    52896000000
# 33   2017-04-02 2017-07-01    45408000000
# 34   2017-07-02 2017-09-30    52579000000
# 35   2017-10-01 2017-12-30    88293000000
# 36   2017-12-31 2018-03-31    61137000000
# 37   2018-04-01 2018-06-30    53265000000
# 38   2018-07-01 2018-09-29    62900000000
# 39   2018-09-30 2018-12-29    84310000000
# 40   2018-12-30 2019-03-30    58015000000
# 41   2019-03-31 2019-06-29    53809000000
# 42   2019-06-30 2019-09-28    64040000000
# 43   2019-09-29 2019-12-28    91819000000
# 44   2019-12-29 2020-03-28    58313000000
# 45   2020-03-29 2020-06-27    59685000000
# 46   2020-06-28 2020-09-26    64698000000
# 47   2020-09-27 2020-12-26   111439000000
# 48   2020-12-27 2021-03-27    89584000000
# 49   2021-03-28 2021-06-26    81434000000
# 50   2021-09-26 2021-12-25   123945000000
# 51   2021-12-26 2022-03-26    97278000000
# 52   2022-03-27 2022-06-25    82959000000
# 53   2023-01-01 2023-04-01    94836000000
# 54   2023-04-02 2023-07-01    81797000000
# 55   2023-10-01 2023-12-30   119575000000
# 56   2023-12-31 2024-03-30    90753000000
# 57   2024-03-31 2024-06-29    85777000000
# 58   2024-09-29 2024-12-28   124300000000
# 59   2024-12-29 2025-03-29    95359000000
# 60   2025-03-30 2025-06-28    94036000000
#
#                                              Tag Used Period Type  FP  Form  \
# 30                                    SalesRevenueNet   Quarterly  FY  10-K
# 31                                    SalesRevenueNet   Quarterly  FY  10-K
# 32                                    SalesRevenueNet   Quarterly  Q2  10-Q
# 33                                    SalesRevenueNet   Quarterly  Q3  10-Q
# 34                                           Revenues   Quarterly  FY  10-K
# 35                                           Revenues   Quarterly  FY  10-K
# 36  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 37  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 38  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  FY  10-K
# 39  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  FY  10-K
# 40  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  FY  10-K
# 41  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 42  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  FY  10-K
# 43  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  FY  10-K
# 44  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 45  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 46  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  FY  10-K
# 47  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q1  10-Q
# 48  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 49  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 50  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q1  10-Q
# 51  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 52  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 53  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 54  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 55  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q1  10-Q
# 56  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 57  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
# 58  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q1  10-Q
# 59  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q2  10-Q
# 60  RevenueFromContractWithCustomerExcludingAssess...   Quarterly  Q3  10-Q
#
#     Period Length (days)  Fiscal Year  Fiscal Year Revenue
# 30                  90.0         2016         215639000000
# 31                  90.0         2016         215639000000
# 32                  90.0         2017         150883000000
# 33                  90.0         2017         150883000000
# 34                  90.0         2017         150883000000
# 35                  90.0         2018         265595000000
# 36                  90.0         2018         265595000000
# 37                  90.0         2018         265595000000
# 38                  90.0         2018         265595000000
# 39                  90.0         2019         260174000000
# 40                  90.0         2019         260174000000
# 41                  90.0         2019         260174000000
# 42                  90.0         2019         260174000000
# 43                  90.0         2020         274515000000
# 44                  90.0         2020         274515000000
# 45                  90.0         2020         274515000000
# 46                  90.0         2020         274515000000
# 47                  90.0         2021         282457000000
# 48                  90.0         2021         282457000000
# 49                  90.0         2021         282457000000
# 50                  90.0         2022         304182000000
# 51                  90.0         2022         304182000000
# 52                  90.0         2022         304182000000
# 53                  90.0         2023         176633000000
# 54                  90.0         2023         176633000000
# 55                  90.0         2024         296105000000
# 56                  90.0         2024         296105000000
# 57                  90.0         2024         296105000000
# 58                  90.0         2025         313695000000
# 59                  90.0         2025         313695000000
# 60                  90.0         2025         313695000000

# %%
#Check for missing quarters

counts = revenue.groupby('Fiscal Year').size()
print(counts)
# Out:
# Fiscal Year
# 2008    1
# 2009    4
# 2010    4
# 2011    4
# 2012    3
# 2013    4
# 2014    4
# 2015    4
# 2016    4
# 2017    3
# 2018    4
# 2019    4
# 2020    4
# 2021    3
# 2022    3
# 2023    2
# 2024    3
# 2025    3
# dtype: int64
