# %%
import pandas as pd

# %%
apple_data=pd.read_csv('/Users/jon/Desktop/Ironhack/Unit 7 - Final Project/Final-Project-Ironhack/Type of analysis/Analisis temporal/Merged files/csv/apple/merged_apple_funadmentals_price_macro.csv')

# %%
apple_data
# Out:
#    calendar_quarter  period_end       Price       revenue   net_income  \
# 0           Q4 2009  2009-12-26    6.326138   15683000000   3378000000
# 1           Q1 2010  2010-03-27    7.054726   13499000000   3074000000
# 2           Q2 2010  2010-06-26    7.550960   15700000000   3253000000
# 3           Q3 2010  2010-09-25    8.518208   20343000000   4308000000
# 4           Q4 2010  2010-12-25    9.683289   26741000000   6004000000
# ..              ...         ...         ...           ...          ...
# 58          Q2 2024  2024-06-29  209.401932   85777000000  21448000000
# 59          Q3 2024  2024-09-28  231.920639   94930000000  14736000000
# 60          Q4 2024  2024-12-28  249.534180  124300000000  36330000000
# 61          Q1 2025  2025-03-29  221.587616   95359000000  24780000000
# 62          Q2 2025  2025-06-28  204.937408   94036000000  23434000000
#
#     ratio assets/libailities  shareholders_equity  gdp_growth  interest_rate
# ...

# %%
#Calculate average revenue growth rate
apple_data['Revenue Growth Rate'] = apple_data['revenue'].pct_change() * 100
avg_revenue_growth_rate = apple_data['Revenue Growth Rate'].mean()
print(f"Average Revenue Growth Rate: {avg_revenue_growth_rate:.2f}%")

#Calculate average net income growth rate
apple_data['Net Income Growth Rate'] = apple_data['net_income'].pct_change() * 100
avg_net_income_growth_rate = apple_data['Net Income Growth Rate'].mean()
print(f"Average Net Income Growth Rate: {avg_net_income_growth_rate:.2f}%")
# Out:
# Average Revenue Growth Rate: 7.42%
# Average Net Income Growth Rate: 11.21%

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(apple_data['period_end'], apple_data['revenue'], label='Revenue', color='blue')
plt.plot(apple_data['period_end'], apple_data['net_income'], label='Net Income', color='green')

plt.xlabel('Period End')
plt.ylabel('Amount')
plt.title('Revenue and Net Income Over Time')
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
